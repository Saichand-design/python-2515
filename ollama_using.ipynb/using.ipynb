# %%
from langchain_core.prompts import chatpromptTemplate
from langchai_ollama.llms import ollamallm

# %%
template = """ context:{input_text}
summarize the given context into 50 words
